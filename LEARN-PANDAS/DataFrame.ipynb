# %%
import pandas as pd

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65089, 70808, 62080, 83080]
}

# %% [markdown]
# ### Creating a Data Frame

# %%
df = pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65089
# 1   Anna   34     Paris   70808
# 2  Peter   29    Berlin   62080
# 3  Linda   42    London   83080

# %%
# Using a list
data_list = [
    ['John', 28, 'New York', 65980],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 65000]
]
df2 = pd.DataFrame(data_list)
df2
# Out:
#        0   1         2      3
# 0   John  28  New York  65980
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  65000

# %%
## add/customize col name
col = ["Name", "Age", "City", "Salary"]
df2 = pd.DataFrame(data_list, columns=col)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65980
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   65000

# %% [markdown]
# ### Selection and Indexing of Columns

# %%
##df[0] # become an error

# select city columns
df["City"]
# Out:
# 0    New York
# 1       Paris
# 2      Berlin
# 3      London
# Name: City, dtype: object

# %%
df.City
# Out:
# 0    New York
# 1       Paris
# 2      Berlin
# 3      London
# Name: City, dtype: object

# %%
# select Name and Age columns together

df[["Name", "Age"]]
# Out:
#     Name  Age
# 0   John   28
# 1   Anna   34
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# ### Creating a new columns

# %%
df["Id"] = [101, 202, 303, 404]

# %%
df
# Out:
#     Name  Age      City  Salary   Id
# 0   John   28  New York   65089  101
# 1   Anna   34     Paris   70808  202
# 2  Peter   29    Berlin   62080  303
# 3  Linda   42    London   83080  404

# %% [markdown]
# ### Removing Cols

# %%
# -------- 0 means x axis, 1 is y axis --------

df.drop("Id", axis=1) # Not remove in actual memory. It's return just a copy
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65089
# 1   Anna   34     Paris   70808
# 2  Peter   29    Berlin   62080
# 3  Linda   42    London   83080

# %%
df.drop(3, axis=0) # Also not remove in actual memory. It's return just a copy
# Out:
#     Name  Age      City  Salary   Id
# 0   John   28  New York   65089  101
# 1   Anna   34     Paris   70808  202
# 2  Peter   29    Berlin   62080  303

# %%
# Permanently remove
df.drop("Id", axis=1, inplace=True)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65089
# 1   Anna   34     Paris   70808
# 2  Peter   29    Berlin   62080
# 3  Linda   42    London   83080

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65089
# 1   Anna   34     Paris   70808
# 2  Peter   29    Berlin   62080
# 3  Linda   42    London   83080

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65089, 70808, 62080, 83080]
}

data_frame = pd.DataFrame(data)
data_frame
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65089
# 1   Anna   34     Paris   70808
# 2  Peter   29    Berlin   62080
# 3  Linda   42    London   83080

# %%
# remove multiple cols
data_frame.drop(["Name", "Age"], axis=1)
# Out:
#        City  Salary
# 0  New York   65089
# 1     Paris   70808
# 2    Berlin   62080
# 3    London   83080

# %% [markdown]
# ### Selecting a Rows

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65089
# 1   Anna   34     Paris   70808
# 2  Peter   29    Berlin   62080
# 3  Linda   42    London   83080

# %%
# df[0]  // getting an error
df.loc[1] # loc = location
# Out:
# Name       Anna
# Age          34
# City      Paris
# Salary    70808
# Name: 1, dtype: object

# %%
# select multiple
df.loc[ [0, 1] ]
# Out:
#    Name  Age      City  Salary
# 0  John   28  New York   65089
# 1  Anna   34     Paris   70808

# %%
# select by index location
df.iloc[0]
# Out:
# Name          John
# Age             28
# City      New York
# Salary       65089
# Name: 0, dtype: object

# %% [markdown]
# ### Selecting subset of rows and cols

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65089
# 1   Anna   34     Paris   70808
# 2  Peter   29    Berlin   62080
# 3  Linda   42    London   83080

# %%
df.loc[[0, 1]] [["City", "Salary"]]
# Out:
#        City  Salary
# 0  New York   65089
# 1     Paris   70808

# %%
df.loc[[]]
# Out:
# Empty DataFrame
# Columns: [Name, Age, City, Salary, Id]
# Index: []

# %% [markdown]
# ### Conditional

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65089
# 1   Anna   34     Paris   70808
# 2  Peter   29    Berlin   62080
# 3  Linda   42    London   83080

# %%
# return those people whose age is greater than 30

df[df["Age"] > 30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70808
# 3  Linda   42  London   83080

# %%
# return those people whose age is greater than 30 and their city must be Paris

df[(df["Age"] > 30) & (df["City"] == "Paris")]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70808

# %% [markdown]
# # Practice

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda', 'Michael', 'Sarah', 'David', 'Emily', 'James', 'Olivia', 'Robert', 'Sophia', 'William', 'Isabella', 'Thomas', 'Charlotte', 'Christopher', 'Amelia', 'Daniel', 'Mia'],
    'Age': [28, 34, 29, 42, 31, 26, 45, 29, 38, 27, 33, 24, 40, 35, 29, 31, 36, 28, 32, 30],
    'City': ['New York', 'Paris', 'Berlin', 'London', 'Tokyo', 'Sydney', 'Toronto', 'Madrid', 'Rome', 'Moscow', 'Seoul', 'Beijing', 'Dubai', 'Mumbai', 'Cairo', 'Rio', 'Chicago', 'Los Angeles', 'Houston', 'Miami'],
    'Salary': [65089, 70808, 62080, 83080, 75000, 68000, 90000, 72000, 71000, 69000, 85000, 67000, 92000, 73000, 64000, 88000, 77000, 82000, 79000, 86000],
    'Department': ['IT', 'HR', 'IT', 'Finance', 'Marketing', 'IT', 'Finance', 'HR', 'IT', 'Marketing', 'Finance', 'IT', 'HR', 'Marketing', 'IT', 'Finance', 'HR', 'IT', 'Marketing', 'Finance'],
    'Experience': [5, 8, 4, 15, 6, 3, 18, 5, 10, 4, 12, 2, 14, 9, 4, 11, 13, 6, 8, 7],
    'Education': ['Bachelor', 'Master', 'Bachelor', 'PhD', 'Bachelor', 'Bachelor', 'Master', 'Bachelor', 'Master', 'Bachelor', 'PhD', 'Bachelor', 'Master', 'Bachelor', 'Bachelor', 'Master', 'PhD', 'Bachelor', 'Master', 'Bachelor'],
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female'],
    'Marital Status': ['Single', 'Married', 'Single', 'Married', 'Single', 'Married', 'Married', 'Single', 'Married', 'Single', 'Married', 'Single', 'Married', 'Single', 'Married', 'Single', 'Married', 'Single', 'Married', 'Single'],
    'Job Title': ['Developer', 'Manager', 'Analyst', 'Director', 'Specialist', 'Developer', 'Director', 'Manager', 'Developer', 'Specialist', 'Director', 'Analyst', 'Manager', 'Specialist', 'Analyst', 'Director', 'Manager', 'Developer', 'Specialist', 'Director']
}
dataFrame = pd.DataFrame(data)
dataFrame
# Out:
#            Name  Age         City  Salary Department  Experience Education  \
# 0          John   28     New York   65089         IT           5  Bachelor
# 1          Anna   34        Paris   70808         HR           8    Master
# 2         Peter   29       Berlin   62080         IT           4  Bachelor
# 3         Linda   42       London   83080    Finance          15       PhD
# 4       Michael   31        Tokyo   75000  Marketing           6  Bachelor
# 5         Sarah   26       Sydney   68000         IT           3  Bachelor
# 6         David   45      Toronto   90000    Finance          18    Master
# 7         Emily   29       Madrid   72000         HR           5  Bachelor
# 8         James   38         Rome   71000         IT          10    Master
# 9        Olivia   27       Moscow   69000  Marketing           4  Bachelor
# 10       Robert   33        Seoul   85000    Finance          12       PhD
# 11       Sophia   24      Beijing   67000         IT           2  Bachelor
# 12      William   40        Dubai   92000         HR          14    Master
# 13     Isabella   35       Mumbai   73000  Marketing           9  Bachelor
# 14       Thomas   29        Cairo   64000         IT           4  Bachelor
# 15    Charlotte   31          Rio   88000    Finance          11    Master
# 16  Christopher   36      Chicago   77000         HR          13       PhD
# 17       Amelia   28  Los Angeles   82000         IT           6  Bachelor
# 18       Daniel   32      Houston   79000  Marketing           8    Master
# 19          Mia   30        Miami   86000    Finance           7  Bachelor
#
#     Gender Marital Status   Job Title
# 0     Male         Single   Developer
# 1   Female        Married     Manager
# 2     Male         Single     Analyst
# 3   Female        Married    Director
# 4     Male         Single  Specialist
# 5   Female        Married   Developer
# 6     Male        Married    Director
# 7   Female         Single     Manager
# 8     Male        Married   Developer
# 9   Female         Single  Specialist
# 10    Male        Married    Director
# 11  Female         Single     Analyst
# 12    Male        Married     Manager
# 13  Female         Single  Specialist
# 14    Male        Married     Analyst
# 15  Female         Single    Director
# 16    Male        Married     Manager
# 17  Female         Single   Developer
# 18    Male        Married  Specialist
# 19  Female         Single    Director

# %%
dataFrame.loc[[10, 11, 12, 13, 14, 15]] [["Name", "Age", "Department"]]
# Out:
#          Name  Age Department
# 10     Robert   33    Finance
# 11     Sophia   24         IT
# 12    William   40         HR
# 13   Isabella   35  Marketing
# 14     Thomas   29         IT
# 15  Charlotte   31    Finance

# %%
# return those people whose age is greater than 20 and their dept. must be IT

dataFrame[ (dataFrame["Age"] > 20) & (dataFrame["Department"] == "IT") ]
# Out:
#       Name  Age         City  Salary Department  Experience Education  Gender  \
# 0     John   28     New York   65089         IT           5  Bachelor    Male
# 2    Peter   29       Berlin   62080         IT           4  Bachelor    Male
# 5    Sarah   26       Sydney   68000         IT           3  Bachelor  Female
# 8    James   38         Rome   71000         IT          10    Master    Male
# 11  Sophia   24      Beijing   67000         IT           2  Bachelor  Female
# 14  Thomas   29        Cairo   64000         IT           4  Bachelor    Male
# 17  Amelia   28  Los Angeles   82000         IT           6  Bachelor  Female
#
#    Marital Status  Job Title
# 0          Single  Developer
# 2          Single    Analyst
# 5         Married  Developer
# 8         Married  Developer
# 11         Single    Analyst
# 14        Married    Analyst
# 17         Single  Developer
